# %%
import pandas as pd
import matplotlib.pyplot as plt

logs = pd.read_csv("../data/user_logs.csv")
logs["category_clicked"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='category_clicked'>
